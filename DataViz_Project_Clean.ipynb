# %%
import altair as alt
import pandas as pd
import numpy as np
from altair.datasets import data

# %% [markdown]
# # Let's take a look at some movies!

# %%
mdf = data.movies()

# %%
mdf
# Out:
#                            Title  US Gross  Worldwide Gross  US DVD Sales  \
# 0                 The Land Girls    146083           146083          <NA>
# 1         First Love, Last Rites     10876            10876          <NA>
# 2     I Married a Strange Person    203134           203134          <NA>
# 3           Let's Talk About Sex    373615           373615          <NA>
# 4                           Slam   1009819          1087521          <NA>
# ...                          ...       ...              ...           ...
# 3196  Zack and Miri Make a Porno  31452765         36851125      21240321
# 3197                      Zodiac  33080084         83080084      20983030
# 3198                        Zoom  11989328         12506188       6679409
# 3199         The Legend of Zorro  45575336        141475336          <NA>
# 3200           The Mask of Zorro  93828745        233700000          <NA>
#
#       Production Budget Release Date MPAA Rating  Running Time min  \
# ...

# %%
mdf.columns
# Out:
# Index(['Title', 'US Gross', 'Worldwide Gross', 'US DVD Sales',
#        'Production Budget', 'Release Date', 'MPAA Rating', 'Running Time min',
#        'Distributor', 'Source', 'Major Genre', 'Creative Type', 'Director',
#        'Rotten Tomatoes Rating', 'IMDB Rating', 'IMDB Votes'],
#       dtype='object')

# %% [markdown]
# # Make a bar graph that shows IMDB rating vs the number of movies with that rating.
#
# ## For this, we'll use a feature of Altair called 'count()'

# %% [markdown]
# # Can we change the color of the bars relating to the count?

# %% [markdown]
# # How about making a line graph plotting release date vs the average (mean) of the movie's rating? (hint: altair also has a mean() feature).

# %% [markdown]
# # Can you show me how many movies were released in each year?

# %% [markdown]
# # Does this data seem right?

# %% [markdown]
# # Can you tell me how many movies were awarded each rating?

# %% [markdown]
# # Or what distributors make the best movies? (hint: find average rating)

# %% [markdown]
# # Airport Count
# ## Put a dot on the centroid of each state, who's size will correspond to the number of airports in that state.
